# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_156 = pd.read_csv('/content/drive/MyDrive/Trabalho DataSet/2022-10-01_156_-_Base_de_Dados-limpo.csv',
                      sep=',', encoding='utf-8')
df_156
# Out:
#     SOLICITACAO         TIPO                               ORGAO        DATA  \
# 0       9671001  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 1       9670915  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 2       9671138  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 3       9671072  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 4       9671351  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 5       9671314  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 6       9671503  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 7       9671565  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 8       9671924  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 9       9671995  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 10      9672044  Solicitação  Instituto das cidades inteligentes  2022-01-09
# ...

# %%
df_156.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SOLICITACAO       58 non-null     int64
#  1   TIPO              58 non-null     object
#  2   ORGAO             58 non-null     object
#  3   DATA              58 non-null     object
#  4   HORARIO           58 non-null     object
#  5   ASSUNTO           58 non-null     object
#  6   SUBDIVISAO        58 non-null     object
#  7   DESCRICAO         58 non-null     object
#  8   LOGRADOURO_ASS    58 non-null     object
#  9   BAIRRO_ASS        58 non-null     object
#  10  REGIONAL_ASS      58 non-null     object
#  11  MEIO_RESPOSTA     58 non-null     object
#  12  OBSERVACAO        58 non-null     object
#  13  SEXO              58 non-null     object
#  14  BAIRRO_CIDADAO    58 non-null     object
#  15  REGIONAL_CIDADAO  58 non-null     object
# ...

# %%
bairrox = df_156.loc[df_156.BAIRRO_ASS == 'Cajuru']
bairrox.shape
# Out:
# (11, 22)

# %%
bairrox.dtypes
# Out:
# SOLICITACAO          int64
# TIPO                object
# ORGAO               object
# DATA                object
# HORARIO             object
# ASSUNTO             object
# SUBDIVISAO          object
# DESCRICAO           object
# LOGRADOURO_ASS      object
# BAIRRO_ASS          object
# REGIONAL_ASS        object
# MEIO_RESPOSTA       object
# OBSERVACAO          object
# SEXO                object
# BAIRRO_CIDADAO      object
# REGIONAL_CIDADAO    object
# DATA_NASC           object
# TIPO_CIDADAO        object
# ORGAO_RESP          object
# RESPOSTA_FINAL      object
# IDADE                int64
# LOGRADOURO_ASS\t    object
# dtype: object

# %%
bairrox.isnull().sum()
# Out:
# SOLICITACAO         0
# TIPO                0
# ORGAO               0
# DATA                0
# HORARIO             0
# ASSUNTO             0
# SUBDIVISAO          0
# DESCRICAO           0
# LOGRADOURO_ASS      0
# BAIRRO_ASS          0
# REGIONAL_ASS        0
# MEIO_RESPOSTA       0
# OBSERVACAO          0
# SEXO                0
# BAIRRO_CIDADAO      0
# REGIONAL_CIDADAO    0
# DATA_NASC           0
# TIPO_CIDADAO        0
# ORGAO_RESP          0
# RESPOSTA_FINAL      0
# IDADE               0
# LOGRADOURO_ASS\t    0
# dtype: int64

# %%
import plotly.express as px
grafico = px.box(bairrox, y="IDADE")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns
sns.histplot(bairrox, x='IDADE', bins=10, color="orange", kde=True, stat="probability");

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
stats.probplot(bairrox['IDADE'], dist="norm", plot=plt)
plt.title("Normal Q-Q plot")
plt.show()

# %%
stats.shapiro(bairrox.IDADE)
# Out:
# ShapiroResult(statistic=0.9073786735534668, pvalue=0.2269921898841858)

# %%
import statsmodels
from statsmodels.stats.diagnostic import lilliefors

# %%
statsmodels.stats.diagnostic.lilliefors(bairrox.IDADE, dist = 'norm')
# Out:
# (0.18362102625800064, 0.384264973288352)

# %% [markdown]
# Teste Z

# %%
bairrox_homem = bairrox.loc[bairrox.SEXO == 'M']
bairrox_homem.head()
# Out:
#     SOLICITACAO         TIPO                               ORGAO        DATA  \
# 46      9678929  Solicitação  Instituto das cidades inteligentes  2022-08-09
# 55      9680979  Solicitação  Instituto das cidades inteligentes  2022-10-09
#
#                            HORARIO ASSUNTO  \
# 46  16:26:35                        Coleta
# 55  12:43:25                        Coleta
#
#                                 SUBDIVISAO  \
# 46             Resíduos vegetais de jardim
# 55  Entulhos diversos (pequena quantidade)
#
#                                             DESCRICAO  \
# 46                   Solicita coleta de lixo vegetal.
# 55  Solicita coleta de entulhos diversos. informa ...
#
#                LOGRADOURO_ASS BAIRRO_ASS  ...  \
# 46  Rua Humberto Giraldi, 415     Cajuru  ...
# 55          Rua Goiânia, 1376     Cajuru  ...
#
#                                  OBSERVACAO SEXO BAIRRO_CIDADAO  \
# 46  Não soube informar ponto de referência.    M        Uberaba
# ...

# %%
bairrox_homem.shape
# Out:
# (2, 22)

# %%
bairrox_mulher = bairrox.loc[bairrox.SEXO == 'F']
bairrox_mulher.head()
# Out:
#     SOLICITACAO         TIPO                               ORGAO        DATA  \
# 8       9671924  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 9       9671995  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 12      9672934  Solicitação  Instituto das cidades inteligentes  2022-02-09
# 21      9673540  Solicitação  Instituto das cidades inteligentes  2022-02-09
# 26      9675154  Solicitação  Instituto das cidades inteligentes  2022-05-09
#
#                            HORARIO ASSUNTO  \
# 8   16:17:35                        Coleta
# 9   17:01:55                        Coleta
# 12  11:04:36                        Coleta
# 21  16:05:58                        Coleta
# 26  01:15:05                        Coleta
#
#                                 SUBDIVISAO  \
# 8   Entulhos diversos (pequena quantidade)
# 9           Caliças até 5 carrinhos de mão
# 12  Entulhos diversos (pequena quantidade)
# 21             Resíduos vegetais de jardim
# ...

# %%
bairrox_mulher.shape
# Out:
# (9, 22)

# %%
import plotly.express as px
grafico = px.box(bairrox_mulher, y="DESCRICAO")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico = px.box(bairrox_homem, y="DESCRICAO")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.histplot(bairrox_mulher, x='DESCRICAO', bins=6, color="red", kde=True, stat="probability");

# %%
sns.histplot(bairrox_homem, x='DESCRICAO', bins=4, color="blue", kde=True, stat="probability");

# %% [markdown]
# Mann Whitney

# %%
stat, p = stats.mannwhitneyu(bairrox_mulher.IDADE, bairrox_homem.IDADE)
print('Estatística de teste: {}'.format(stat.round(2)))
print('p-valor: {}'.format(p))
# Out:
# Estatística de teste: 18.0
# p-valor: 0.03636363636363636

# %%
bairrox_mulher.IDADE.describe()
# Out:
# count     9.000000
# mean     70.333333
# std      10.920165
# min      49.000000
# 25%      65.000000
# 50%      71.000000
# 75%      79.000000
# max      84.000000
# Name: IDADE, dtype: float64

# %%
bairrox_homem.IDADE.describe()
# Out:
# count     2.000000
# mean     33.000000
# std       9.899495
# min      26.000000
# 25%      29.500000
# 50%      33.000000
# 75%      36.500000
# max      40.000000
# Name: IDADE, dtype: float64

# %%
grafico = px.box(bairrox, x = 'IDADE', y="DESCRICAO")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico = px.box(bairrox, x = 'IDADE', y="DESCRICAO")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
