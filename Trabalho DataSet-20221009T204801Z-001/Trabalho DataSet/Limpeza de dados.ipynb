# %%
#importação de bibliotecas
import pandas as pd

# %matplotlib inline

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)

# lê o arquivo CSV
df = pd.read_csv('/content/drive/MyDrive/Trabalho DataSet/2022-09-16_Alvaras_-_Base_de_Dados.csv', encoding='latin-1', sep=';')
# Out:
# Mounted at /content/drive

# %%
df.head()
# Out:
#                                     NOME_EMPRESARIAL INICIO_ATIVIDADE  \
# 0                   +55 ADMINISTRADORA DE BENS LTDA.       24/03/2016
# 1           0 STELLA SERVICOS E COMERCIO DE CARIMBOS       24/04/2003
# 2  001SHOP DESENVOLVIMENTO DE LOJAS VIRTUAIS LTDA...       03/04/2012
# 3                            007 INFORMATICA LTDA ME       30/03/2012
# 4                     007 TRANSPORTE RODOVIARIO LTDA       07/06/1999
#
#    NUMERO_DO_ALVARA                                    NOME_DA_EMPRESA  \
# 0           1351366                    +55 ADMINISTRADORA DE BENS LTDA
# 1            969243                                                ***
# 2           1624518  001SHOP DESENVOLVIMENTO DE LOJAS VIRTUAIS LTDA...
# 3           1068718                                    007 INFORMATICA
# 4            484163                     007 TRANSPORTE RODOVIARIO LTDA
#
#   DATA_EMISSAO DATA_EXPIRACAO  \
# 0   20/12/2017            ***
# 1   01/12/2010            ***
# 2   21/02/2022            ***
# 3   30/05/2012            ***
# 4   14/09/1999     31/12/2002
#
#                                  ATIVIDADE_PRINCIPAL  \
# 0  GESTÃO E ADMINISTRAÇÃO DA PROPRIEDADE IMOBILIÁRIA
# 1         COMÉRCIO VAREJISTA DE ARTIGOS DE PAPELARIA
# 2  TRATAMENTO DE DADOS, PROVEDORES DE SERVIÇOS DE...
# 3                         SALAS DE ACESSO À INTERNET
# 4  TRANSPORTE RODOVIÁRIO DE CARGA, EXCETO PRODUTO...
#
#                                ATIVIDADE_SECUNDARIA1  \
# 0                     LOTEAMENTO DE IMÓVEIS PRÓPRIOS
# 1  SERVIÇOS DE ACABAMENTOS GRÁFICOS, EXCETO ENCAD...
# 2  PREPARAÇÃO DE DOCUMENTOS E SERVIÇOS ESPECIALIZ...
# 3  COMÉRCIO VAREJISTA ESPECIALIZADO DE EQUIPAMENT...
# 4                                                ***
#
#                                ATIVIDADE_SECUNDARIA2  \
# 0                        ALUGUEL DE IMÓVEIS PRÓPRIOS
# 1  SERVIÇOS DE GRAVAÇÃO DE CARIMBOS, EXCETO CONFE...
# 2                                                ***
# 3  REPARAÇÃO E MANUTENÇÃO DE COMPUTADORES E DE EQ...
# 4                                                ***
#
#                         ENDERECO  NUMERO UNIDADE ANDAR COMPLEMENTO  \
# 0              R. EVALDO WENDLER  000090    CS68   NaN         NaN
# 1  R. MANOEL SILVÉRIO DOS SANTOS     000     NaN   NaN         NaN
# 2                 R. LUIZ RONALD     NaN     NaN   NaN         NaN
# 3          EST. DE SANTA CÂNDIDA  000941     ***   ***         ***
# 4               R. TREZE DE MAIO  000336      61     6          AD
#
#          BAIRRO       CEP
# 0  SÃO LOURENÇO       822
# 1           NaN       NaN
# 2           NaN       NaN
# 3  SANTA CÂNDID       NaN
# 4        CENTRO  80020270

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483662 entries, 0 to 483661
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   NOME_EMPRESARIAL       483662 non-null  object
#  1   INICIO_ATIVIDADE       483662 non-null  object
#  2   NUMERO_DO_ALVARA       483662 non-null  int64
#  3   NOME_DA_EMPRESA        483143 non-null  object
#  4   DATA_EMISSAO           483662 non-null  object
#  5   DATA_EXPIRACAO         483662 non-null  object
#  6   ATIVIDADE_PRINCIPAL    483662 non-null  object
#  7   ATIVIDADE_SECUNDARIA1  483662 non-null  object
#  8   ATIVIDADE_SECUNDARIA2  483662 non-null  object
#  9   ENDERECO               462769 non-null  object
#  10  NUMERO                 423524 non-null  object
#  11  UNIDADE                388219 non-null  object
#  12  ANDAR                  375630 non-null  object
#  13  COMPLEMENTO            363874 non-null  object
#  14  BAIRRO                 384205 non-null  object
#  15  CEP                    361953 non-null  object
# dtypes: int64(1), object(15)
# memory usage: 59.0+ MB

# %%
df[df.isna().any(axis=1)]
# Out:
#                                          NOME_EMPRESARIAL INICIO_ATIVIDADE  \
# 0                        +55 ADMINISTRADORA DE BENS LTDA.       24/03/2016
# 1                0 STELLA SERVICOS E COMERCIO DE CARIMBOS       24/04/2003
# 2       001SHOP DESENVOLVIMENTO DE LOJAS VIRTUAIS LTDA...       03/04/2012
# 3                                 007 INFORMATICA LTDA ME       30/03/2012
# 5                    01 TECNOLOGIA DA INFORMACAO LTDA. ME       12/01/2012
# ...                                                   ...              ...
# 483655                                ZY COMUNICACAO LTDA       01/02/2005
# 483657  ZYVYABOK COMERCIAL EXPORTADORA E IMPORTADORA D...       19/02/2019
# 483658       ZZ CENTRO AUTOMOTIVO E OFICINA MECANICA LTDA       30/06/2020
# 483659   ZZA - COMERCIO DE ALIMENTOS E BEBIDAS LTDA - EPP       14/08/2013
# 483661           ZZCM COMÉRCIO E COLOCAÇÃO DE PISOS LTDA.       05/05/2003
#
#         NUMERO_DO_ALVARA                                    NOME_DA_EMPRESA  \
# 0                1351366                    +55 ADMINISTRADORA DE BENS LTDA
# 1                 969243                                                ***
# 2                1624518  001SHOP DESENVOLVIMENTO DE LOJAS VIRTUAIS LTDA...
# 3                1068718                                    007 INFORMATICA
# 5                1057425               01 TECNOLOGIA DA INFORMACAO LTDA. ME
# ...                  ...                                                ...
# 483655           1106867                                        COMUNNICARE
# 483657           1641039  ZYVYABOK COMERCIAL EXPORTADORA E IMPORTADORA D...
# 483658           1503516            ZZ CENTRO AUTOMOTIVO E OFICINA MECANICA
# 483659           1273972         ZZA - COMERCIO DE ALIMENTOS E BEBIDAS LTDA
# 483661            957924                                                ***
#
#        DATA_EMISSAO DATA_EXPIRACAO  \
# 0        20/12/2017            ***
# 1        01/12/2010            ***
# 2        21/02/2022            ***
# 3        30/05/2012            ***
# 5        01/03/2012            ***
# ...             ...            ...
# 483655   28/11/2012            ***
# 483657   18/05/2022            ***
# 483658   30/06/2020            ***
# 483659   24/06/2016            ***
# 483661   01/12/2010            ***
#
#                                       ATIVIDADE_PRINCIPAL  \
# 0       GESTÃO E ADMINISTRAÇÃO DA PROPRIEDADE IMOBILIÁRIA
# 1              COMÉRCIO VAREJISTA DE ARTIGOS DE PAPELARIA
# 2       TRATAMENTO DE DADOS, PROVEDORES DE SERVIÇOS DE...
# 3                              SALAS DE ACESSO À INTERNET
# 5       DESENVOLVIMENTO DE PROGRAMAS DE COMPUTADOR SOB...
# ...                                                   ...
# 483655  ATIVIDADES DE CONSULTORIA EM GESTÃO EMPRESARIA...
# 483657  COMÉRCIO ATACADISTA DE MADEIRA E PRODUTOS DERI...
# 483658  COMÉRCIO A VAREJO DE PEÇAS E ACESSÓRIOS NOVOS ...
# 483659                           RESTAURANTES E SIMILARES
# 483661  APLICAÇÃO DE REVESTIMENTOS E DE RESINAS EM INT...
#
#                                     ATIVIDADE_SECUNDARIA1  \
# 0                          LOTEAMENTO DE IMÓVEIS PRÓPRIOS
# 1       SERVIÇOS DE ACABAMENTOS GRÁFICOS, EXCETO ENCAD...
# 2       PREPARAÇÃO DE DOCUMENTOS E SERVIÇOS ESPECIALIZ...
# 3       COMÉRCIO VAREJISTA ESPECIALIZADO DE EQUIPAMENT...
# 5       ALUGUEL DE MÁQUINAS E EQUIPAMENTOS PARA ESCRIT...
# ...                                                   ...
# 483655  DESENVOLVIMENTO DE PROGRAMAS DE COMPUTADOR SOB...
# 483657                            COMISSARIA DE DESPACHOS
# 483658  SERVIÇOS DE ALINHAMENTO E BALANCEAMENTO DE VEÍ...
# 483659                                                ***
# 483661  COMÉRCIO VAREJISTA DE ARTIGOS DE DECORAÇÃO PAR...
#
#                                     ATIVIDADE_SECUNDARIA2  \
# 0                             ALUGUEL DE IMÓVEIS PRÓPRIOS
# 1       SERVIÇOS DE GRAVAÇÃO DE CARIMBOS, EXCETO CONFE...
# 2                                                     ***
# 3       REPARAÇÃO E MANUTENÇÃO DE COMPUTADORES E DE EQ...
# 5          TRATAMENTO DE DADOS, PROVEDORES DE SERVIÇOS DE
# ...                                                   ...
# 483655                         CONSULTORIA EM PUBLICIDADE
# 483657      COMÉRCIO ATACADISTA DE CARNES E DERIVADOS DE
# 483658                SERVIÇOS DE MANUTENÇÃO E REPARAÇÃO
# 483659                                                ***
# 483661  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
#
#                               ENDERECO  NUMERO UNIDADE ANDAR COMPLEMENTO  \
# 0                    R. EVALDO WENDLER  000090    CS68   NaN         NaN
# 1        R. MANOEL SILVÉRIO DOS SANTOS     000     NaN   NaN         NaN
# 2                       R. LUIZ RONALD     NaN     NaN   NaN         NaN
# 3                EST. DE SANTA CÂNDIDA  000941     ***   ***         ***
# 5                                  NaN     NaN     NaN   NaN         NaN
# ...                                ...     ...     ...   ...         ...
# 483655  R. JOÃO CARLOS DE SOUZA CASTRO  000743     ***   ***         ***
# 483657                             NaN     NaN     NaN   NaN         NaN
# 483658                             NaN     NaN     NaN   NaN         NaN
# 483659                    AV. DO BATEL  001868     NaN   NaN         NaN
# 483661                    R. RIO NEGRO  000155     ***     *         NaN
#
#               BAIRRO       CEP
# 0       SÃO LOURENÇO       822
# 1                NaN       NaN
# 2                NaN       NaN
# 3       SANTA CÂNDID       NaN
# 5                NaN       NaN
# ...              ...       ...
# 483655   GUABIROTUBA       NaN
# 483657           NaN       NaN
# 483658           NaN       NaN
# 483659         BATEL  80420090
# 483661           NaN       NaN
#
# [150736 rows x 16 columns]

# %%
df['endereco'] = df['endereco'].fillna("Desconhecido")

df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [codigo, endereco, quartos, suite, area, vaga, aluguel, condominio, data]
# Index: []
