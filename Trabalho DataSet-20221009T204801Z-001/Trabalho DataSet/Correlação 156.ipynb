# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
sheet_url = "https://docs.google.com/spreadsheets/d/1BGSuePG58cTB_JY406ll_qSNLQ4qipO9k-IZ75OIIu0/edit#gid=477985435"
url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df = pd.read_csv(url)

# %%
df.head()
# Out:
#    SOLICITACAO         TIPO                               ORGAO        DATA  \
# 0      9671001  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 1      9670915  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 2      9671138  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 3      9671072  Solicitação  Instituto das cidades inteligentes  2022-01-09
# 4      9671351  Solicitação  Instituto das cidades inteligentes  2022-01-09
#
#     HORARIO ASSUNTO                      SUBDIVISAO  \
# 0  09:04:31  Coleta     Resíduos vegetais de jardim
# 1  07:53:25  Coleta     Resíduos vegetais de jardim
# 2  10:02:18  Coleta     Resíduos vegetais de jardim
# 3  09:35:03  Coleta  Caliças até 5 carrinhos de mão
# 4  11:28:00  Coleta  Caliças até 5 carrinhos de mão
#
#                           DESCRICAO  \
# 0  Solicita coleta de lixo vegetal.
# 1  Solicita coleta de lixo vegetal.
# 2  Solicita coleta de lixo vegetal.
# 3       Solicita coleta de caliças.
# ...

# %%
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

sns.set()
sns.scatterplot(data=df, x=df['IDADE'], y=df['BAIRRO_ASS'])

# %%
sns.scatterplot(data=df, x=df['IDADE'], y=df['BAIRRO_ASS'], hue=df['SEXO'])

# %%
sns.relplot(
    data=df, x=df['IDADE'], y=df['BAIRRO_ASS'],
    col=df['SEXO'],
    kind="scatter"
)

# %%
sns.relplot(
    data=df, x=df['IDADE'], y=df['REGIONAL_CIDADAO'],
    col=df['SEXO'],
    kind="scatter"
)

# %%
sns.relplot(
    data=df, x=df['IDADE'], y=df['REGIONAL_CIDADAO'],
    col=df['TIPO'],
    kind="scatter"
)

# %%
sns.pairplot(data=df, hue='TIPO', corner=False)

# %%
sns.pairplot(data=df, hue='REGIONAL_CIDADAO', corner=False)

# %%
df.corr()
# Out:
#              SOLICITACAO     IDADE
# SOLICITACAO     1.000000 -0.027993
# IDADE          -0.027993  1.000000

# %%
corr = df.corr()

# %%
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# %%
sns.heatmap(df.corr(),cmap=cmap, annot=True);
