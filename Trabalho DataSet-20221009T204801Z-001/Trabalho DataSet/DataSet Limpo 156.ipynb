# %%
#importação de bibliotecas
import pandas as pd

# %matplotlib inline

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)

# lê o arquivo CSV
df = pd.read_csv('/content/drive/MyDrive/Trabalho DataSet/2022-10-01_156_-_Base_de_Dados.csv', encoding='latin-1', sep=';', on_bad_lines='skip')
# Out:
# Mounted at /content/drive

# %%
df.head()
# Out:
#              SOLICITACAO                  TIPO  \
# 0  ---------------------               -------
# 1                9670968           Solicitação
# 2                    NaN  SOLICITACAO ATENDIDA
# 3                9670924           Solicitação
# 4                    NaN  SOLICITACAO ATENDIDA
#
#                                 ORGAO                            DATA  \
# 0                        ------------                        --------
# 1  INSTITUTO DAS CIDADES INTELIGENTES  01/09/2022
# 2                                 NaN                             NaN
# 3  INSTITUTO DAS CIDADES INTELIGENTES  01/09/2022
# 4                                 NaN                             NaN
#
#                           HORARIO          ASSUNTO  \
# 0                 ---------------  ---------------
# 1  08:45:13                                 Coleta
# 2                             NaN              NaN
# 3  07:59:39                                 Coleta
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SOLICITACAO       212 non-null    object
#  1   TIPO              423 non-null    object
#  2   ORGAO             212 non-null    object
#  3   DATA              212 non-null    object
#  4   HORARIO           212 non-null    object
#  5   ASSUNTO           212 non-null    object
#  6   SUBDIVISAO        212 non-null    object
#  7   DESCRICAO         212 non-null    object
#  8   LOGRADOURO_ASS    212 non-null    object
#  9   BAIRRO_ASS        212 non-null    object
#  10  REGIONAL_ASS      212 non-null    object
#  11  MEIO_RESPOSTA     212 non-null    object
#  12  OBSERVACAO        60 non-null     object
#  13  SEXO              211 non-null    object
#  14  BAIRRO_CIDADAO    212 non-null    object
#  15  REGIONAL_CIDADAO  210 non-null    object
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
#     SOLICITACAO                  TIPO                               ORGAO  \
# 1       9670968           Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 2           NaN  SOLICITACAO ATENDIDA                                 NaN
# 3       9670924           Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 4           NaN  SOLICITACAO ATENDIDA                                 NaN
# 5       9670990           Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# ..          ...                   ...                                 ...
# 417     9698747           Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 418         NaN  SOLICITACAO ATENDIDA                                 NaN
# 420         NaN  SOLICITACAO ATENDIDA                                 NaN
# 421     9702426           Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 422         NaN  SOLICITACAO ATENDIDA                                 NaN
#
#                                DATA                         HORARIO ASSUNTO  \
# ...

# %%
# Resposta:
df.dropna(inplace=True)

df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [SOLICITACAO, TIPO, ORGAO, DATA, HORARIO, ASSUNTO, SUBDIVISAO, DESCRICAO, LOGRADOURO_ASS, BAIRRO_ASS, REGIONAL_ASS, MEIO_RESPOSTA, OBSERVACAO, SEXO, BAIRRO_CIDADAO, REGIONAL_CIDADAO, DATA_NASC, TIPO_CIDADAO, ORGAO_RESP, RESPOSTA_FINAL]
# Index: []

# %%
df.head()
# Out:
#               SOLICITACAO         TIPO                               ORGAO  \
# 0   ---------------------      -------                        ------------
# 9                 9671001  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 11                9670915  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 31                9671138  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 33                9671072  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
#
#                               DATA                         HORARIO  \
# 0                         --------                 ---------------
# 9   01/09/2022                      09:04:31
# 11  01/09/2022                      07:53:25
# 31  01/09/2022                      10:02:18
# 33  01/09/2022                      09:35:03
#
#             ASSUNTO                      SUBDIVISAO  \
# 0   ---------------             -------------------
# 9            Coleta     Resíduos vegetais de jardim
# ...

# %%
df['RESPOSTA_FINAL'].unique()
# Out:
# array(['----------------------------', 'Retirada da Pendência de Revisão'],
#       dtype=object)

# %%
df[df['RESPOSTA_FINAL'] == '----------------------------']
# Out:
#              SOLICITACAO     TIPO         ORGAO      DATA          HORARIO  \
# 0  ---------------------  -------  ------------  --------  ---------------
#
#            ASSUNTO           SUBDIVISAO              DESCRICAO  \
# 0  ---------------  -------------------  ---------------------
#
#                     LOGRADOURO_ASS             BAIRRO_ASS  \
# 0  -------------------------------  ---------------------
#
#                 REGIONAL_ASS                MEIO_RESPOSTA  \
# 0  -------------------------  ---------------------------
#
#                 OBSERVACAO       SEXO                BAIRRO_CIDADAO  \
# 0  -----------------------  ---------  ----------------------------
#
#                     REGIONAL_CIDADAO            DATA_NASC  \
# 0  ---------------------------------  -------------------
#
#               TIPO_CIDADAO               ORGAO_RESP  \
# 0  -----------------------  -----------------------
#
#                  RESPOSTA_FINAL
# 0  ----------------------------

# %%
df = df.drop(0)

# %%
df
# Out:
#     SOLICITACAO         TIPO                               ORGAO  \
# 9       9671001  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 11      9670915  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 31      9671138  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 33      9671072  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 43      9671351  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 47      9671314  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 53      9671503  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 57      9671565  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 93      9671924  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 105     9671995  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 107     9672044  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 123     9672740  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# 133     9672934  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 9 to 419
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SOLICITACAO       58 non-null     object
#  1   TIPO              58 non-null     object
#  2   ORGAO             58 non-null     object
#  3   DATA              58 non-null     object
#  4   HORARIO           58 non-null     object
#  5   ASSUNTO           58 non-null     object
#  6   SUBDIVISAO        58 non-null     object
#  7   DESCRICAO         58 non-null     object
#  8   LOGRADOURO_ASS    58 non-null     object
#  9   BAIRRO_ASS        58 non-null     object
#  10  REGIONAL_ASS      58 non-null     object
#  11  MEIO_RESPOSTA     58 non-null     object
#  12  OBSERVACAO        58 non-null     object
#  13  SEXO              58 non-null     object
#  14  BAIRRO_CIDADAO    58 non-null     object
#  15  REGIONAL_CIDADAO  58 non-null     object
# ...

# %%
df['DATA'] = pd.to_datetime(df['DATA'])
df['DATA_NASC'] = pd.to_datetime(df['DATA_NASC'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 9 to 419
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SOLICITACAO       58 non-null     object
#  1   TIPO              58 non-null     object
#  2   ORGAO             58 non-null     object
#  3   DATA              58 non-null     datetime64[ns]
#  4   HORARIO           58 non-null     object
#  5   ASSUNTO           58 non-null     object
#  6   SUBDIVISAO        58 non-null     object
#  7   DESCRICAO         58 non-null     object
#  8   LOGRADOURO_ASS    58 non-null     object
#  9   BAIRRO_ASS        58 non-null     object
#  10  REGIONAL_ASS      58 non-null     object
#  11  MEIO_RESPOSTA     58 non-null     object
#  12  OBSERVACAO        58 non-null     object
#  13  SEXO              58 non-null     object
#  14  BAIRRO_CIDADAO    58 non-null     object
#  15  REGIONAL_CIDADAO  58 non-null     object
# ...

# %%
df
# Out:
#     SOLICITACAO         TIPO                               ORGAO       DATA  \
# 9       9671001  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 11      9670915  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 31      9671138  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 33      9671072  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 43      9671351  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 47      9671314  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 53      9671503  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 57      9671565  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 93      9671924  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 105     9671995  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 107     9672044  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# ...

# %%
df['IDADE'] = df['DATA'].dt.year - df['DATA_NASC'].dt.year 
df
# Out:
#     SOLICITACAO         TIPO                               ORGAO       DATA  \
# 9       9671001  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 11      9670915  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 31      9671138  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 33      9671072  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 43      9671351  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 47      9671314  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 53      9671503  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 57      9671565  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 93      9671924  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 105     9671995  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# 107     9672044  Solicitação  INSTITUTO DAS CIDADES INTELIGENTES 2022-01-09
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 9 to 419
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SOLICITACAO       58 non-null     object
#  1   TIPO              58 non-null     object
#  2   ORGAO             58 non-null     object
#  3   DATA              58 non-null     datetime64[ns]
#  4   HORARIO           58 non-null     object
#  5   ASSUNTO           58 non-null     object
#  6   SUBDIVISAO        58 non-null     object
#  7   DESCRICAO         58 non-null     object
#  8   LOGRADOURO_ASS    58 non-null     object
#  9   BAIRRO_ASS        58 non-null     object
#  10  REGIONAL_ASS      58 non-null     object
#  11  MEIO_RESPOSTA     58 non-null     object
#  12  OBSERVACAO        58 non-null     object
#  13  SEXO              58 non-null     object
#  14  BAIRRO_CIDADAO    58 non-null     object
#  15  REGIONAL_CIDADAO  58 non-null     object
# ...

# %%
df['DESCRICAO'] = df['DESCRICAO'].str.lower()
df['DESCRICAO'].unique()
# Out:
# array(['solicita coleta de lixo vegetal.', 'solicita coleta de caliças.',
#        'solicita coleta de entulhos diversos.',
#        'solicita análise para coleta de lixo vegetal acima da quantidade. ',
#        'solicita recadastro do protocolo 009657034 referente à não atendimento. segue descrição: solicita coleta de lixo vegetal.',
#        'solicita coleta de resíduos de jardim em grande quantidade. informa que está atrapalhando a via e parte do passeio e provavelmente foi colocado por terceiros. ',
#        'solicita coleta de entulhos que foram deixados anexo a uma placa que tem no local. informa que são espelhos quebrados e pontiagudos. ressalta que não pode sair de casa para separa o lixo porque está em isolamento devido covid. pede urgência.',
# ...

# %%
df.head()
# Out:
#    SOLICITACAO         TIPO                               ORGAO       DATA  \
# 9      9671001  Solicitação  instituto das cidades inteligentes 2022-01-09
# 11     9670915  Solicitação  instituto das cidades inteligentes 2022-01-09
# 31     9671138  Solicitação  instituto das cidades inteligentes 2022-01-09
# 33     9671072  Solicitação  instituto das cidades inteligentes 2022-01-09
# 43     9671351  Solicitação  instituto das cidades inteligentes 2022-01-09
#
#                            HORARIO ASSUNTO                      SUBDIVISAO  \
# 9   09:04:31                        Coleta     Resíduos vegetais de jardim
# 11  07:53:25                        Coleta     Resíduos vegetais de jardim
# 31  10:02:18                        Coleta     Resíduos vegetais de jardim
# 33  09:35:03                        Coleta  Caliças até 5 carrinhos de mão
# 43  11:28:00                        Coleta  Caliças até 5 carrinhos de mão
#
#                            DESCRICAO  \
# ...

# %%
df['DESCRICAO'] = df['DESCRICAO'].str.capitalize()

# %%
df['BAIRRO_ASS'] = df['BAIRRO_ASS'].str.title()

# %%
df
# Out:
#     SOLICITACAO         TIPO                               ORGAO       DATA  \
# 9       9671001  Solicitação  Instituto das cidades inteligentes 2022-09-01
# 11      9670915  Solicitação  Instituto das cidades inteligentes 2022-09-01
# 31      9671138  Solicitação  Instituto das cidades inteligentes 2022-09-01
# 33      9671072  Solicitação  Instituto das cidades inteligentes 2022-09-01
# 43      9671351  Solicitação  Instituto das cidades inteligentes 2022-09-01
# 47      9671314  Solicitação  Instituto das cidades inteligentes 2022-09-01
# 53      9671503  Solicitação  Instituto das cidades inteligentes 2022-09-01
# 57      9671565  Solicitação  Instituto das cidades inteligentes 2022-09-01
# 93      9671924  Solicitação  Instituto das cidades inteligentes 2022-09-01
# 105     9671995  Solicitação  Instituto das cidades inteligentes 2022-09-01
# 107     9672044  Solicitação  Instituto das cidades inteligentes 2022-09-01
# ...

# %%
df.to_csv('/content/drive/MyDrive/Trabalho DataSet/2022-10-01_156_-_Base_de_Dados-limpo.csv', index=False)
